# %%
import numpy as np
import pandas as pd
import seaborn as sns
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, WeightedRandomSampler

from sklearn.preprocessing import MinMaxScaler    
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

# %%
df = pd.read_csv("winequality-red.csv")
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
sns.countplot(x = 'quality', data=df)
# Out:
# <Axes: xlabel='quality', ylabel='count'>

# %%
# Encode Output Class
# Next, we see that the output labels are from 3 to 8. That needs to change because PyTorch supports labels starting from 0. That is [0, n]. We need to remap our labels to start from 0.
# To do that, let’s create a dictionary called class2idx and use the .replace() method from the Pandas library to change it. Let’s also create a reverse mapping called idx2class which converts the IDs back to their original classes.
# To create the reverse mapping, we create a dictionary comprehension and simply reverse the key and value.
class2idx = {
    3:0,
    4:1,
    5:2,
    6:3,
    7:4,
    8:5
}

idx2class = {v: k for k, v in class2idx.items()}

df['quality'].replace(class2idx, inplace=True)

# %%
X = df.iloc[:, 0:-1]
y = df.iloc[:, -1]

# %%
# Split into train+val and test
X_trainval, X_test, y_trainval, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=69)

# Split train into train-val
X_train, X_val, y_train, y_val = train_test_split(X_trainval, y_trainval, test_size=0.1, stratify=y_trainval, random_state=21)

# %%
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)
X_test = scaler.transform(X_test)
X_train, y_train = np.array(X_train), np.array(y_train)
X_val, y_val = np.array(X_val), np.array(y_val)
X_test, y_test = np.array(X_test), np.array(y_test)

# %%
def get_class_distribution(obj):
    count_dict = {
        "rating_3": 0,
        "rating_4": 0,
        "rating_5": 0,
        "rating_6": 0,
        "rating_7": 0,
        "rating_8": 0,
    }
    
    for i in obj:
        if i == 0: 
            count_dict['rating_3'] += 1
        elif i == 1: 
            count_dict['rating_4'] += 1
        elif i == 2: 
            count_dict['rating_5'] += 1
        elif i == 3: 
            count_dict['rating_6'] += 1
        elif i == 4: 
            count_dict['rating_7'] += 1  
        elif i == 5: 
            count_dict['rating_8'] += 1              
        else:
            print("Check classes.")
            
    return count_dict

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(25,7))
# Train
sns.barplot(data = pd.DataFrame.from_dict([get_class_distribution(y_train)]).melt(), x = "variable", y="value", hue="variable",  ax=axes[0]).set_title('Class Distribution in Train Set')
# Validation
sns.barplot(data = pd.DataFrame.from_dict([get_class_distribution(y_val)]).melt(), x = "variable", y="value", hue="variable",  ax=axes[1]).set_title('Class Distribution in Val Set')
# Test
sns.barplot(data = pd.DataFrame.from_dict([get_class_distribution(y_test)]).melt(), x = "variable", y="value", hue="variable",  ax=axes[2]).set_title('Class Distribution in Test Set')
# Out:
# Text(0.5, 1.0, 'Class Distribution in Test Set')

# %%
class ClassifierDataset(Dataset):
    
    def __init__(self, X_data, y_data):
        self.X_data = X_data
        self.y_data = y_data
        
    def __getitem__(self, index):
        return self.X_data[index], self.y_data[index]
        
    def __len__ (self):
        return len(self.X_data)


train_dataset = ClassifierDataset(torch.from_numpy(X_train).float(), torch.from_numpy(y_train).long())
val_dataset = ClassifierDataset(torch.from_numpy(X_val).float(), torch.from_numpy(y_val).long())
test_dataset = ClassifierDataset(torch.from_numpy(X_test).float(), torch.from_numpy(y_test).long())

# %%
target_list = []
for _, t in train_dataset:
    target_list.append(t)
    
target_list = torch.tensor(target_list)

# %%
class_count = [i for i in get_class_distribution(y_train).values()]
class_weights = 1./torch.tensor(class_count, dtype=torch.float) 
print(class_weights)
# Out:
# tensor([0.1429, 0.0263, 0.0020, 0.0022, 0.0070, 0.0714])

# %%
class_weights_all = class_weights[target_list]

# %%
weighted_sampler = WeightedRandomSampler(
    weights=class_weights_all,
    num_samples=len(class_weights_all),
    replacement=True
)

# %%
EPOCHS = 300
BATCH_SIZE = 16
LEARNING_RATE = 0.0007
NUM_FEATURES = len(X.columns)
NUM_CLASSES = 6

# %%
train_loader = DataLoader(dataset=train_dataset,
                          batch_size=BATCH_SIZE,
                          sampler=weighted_sampler
)
val_loader = DataLoader(dataset=val_dataset, batch_size=1)
test_loader = DataLoader(dataset=test_dataset, batch_size=1)

# %%
class MulticlassClassification(nn.Module):
    def __init__(self, num_feature, num_class):
        super(MulticlassClassification, self).__init__()
        
        self.layer_1 = nn.Linear(num_feature, 512)
        self.layer_2 = nn.Linear(512, 128)
        self.layer_3 = nn.Linear(128, 64)
        self.layer_out = nn.Linear(64, num_class) 
        
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(p=0.2)
        self.batchnorm1 = nn.BatchNorm1d(512)
        self.batchnorm2 = nn.BatchNorm1d(128)
        self.batchnorm3 = nn.BatchNorm1d(64)
        
    def forward(self, x):
        x = self.layer_1(x)
        x = self.batchnorm1(x)
        x = self.relu(x)
        
        x = self.layer_2(x)
        x = self.batchnorm2(x)
        x = self.relu(x)
        x = self.dropout(x)
        
        x = self.layer_3(x)
        x = self.batchnorm3(x)
        x = self.relu(x)
        x = self.dropout(x)
        
        x = self.layer_out(x)
        
        return x

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cpu

# %%
# Initialize the model, optimizer, and loss function.
#  Transfer the model to GPU. We’re using the 
# nn.CrossEntropyLoss because this is a multiclass classification problem. We don’t have to manually apply a log_softmax layer after our final layer because nn.CrossEntropyLoss does that for us. However, we need to apply log_softmax for our validation and testing.


model = MulticlassClassification(num_feature = NUM_FEATURES, num_class=NUM_CLASSES)
model.to(device)

criterion = nn.CrossEntropyLoss(weight=class_weights.to(device))
optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)
print(model)
# Out:
# MulticlassClassification(
#   (layer_1): Linear(in_features=11, out_features=512, bias=True)
#   (layer_2): Linear(in_features=512, out_features=128, bias=True)
#   (layer_3): Linear(in_features=128, out_features=64, bias=True)
#   (layer_out): Linear(in_features=64, out_features=6, bias=True)
#   (relu): ReLU()
#   (dropout): Dropout(p=0.2, inplace=False)
#   (batchnorm1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batchnorm2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batchnorm3): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )

# %%
def multi_acc(y_pred, y_test):
    y_pred_softmax = torch.log_softmax(y_pred, dim = 1)
    _, y_pred_tags = torch.max(y_pred_softmax, dim = 1)    
    
    correct_pred = (y_pred_tags == y_test).float()
    acc = correct_pred.sum() / len(correct_pred)
    
    acc = torch.round(acc * 100)
    
    return acc

# %%
accuracy_stats = {
    'train': [],
    "val": []
}
loss_stats = {
    'train': [],
    "val": []
}

# %%
print("Begin training.")
for e in tqdm(range(1, EPOCHS+1)):
    
    # TRAINING
    train_epoch_loss = 0
    train_epoch_acc = 0
    model.train()
    for X_train_batch, y_train_batch in train_loader:
        X_train_batch, y_train_batch = X_train_batch.to(device), y_train_batch.to(device)
        optimizer.zero_grad()
        
        y_train_pred = model(X_train_batch)
        
        train_loss = criterion(y_train_pred, y_train_batch)
        train_acc = multi_acc(y_train_pred, y_train_batch)
        
        train_loss.backward()
        optimizer.step()
        
        train_epoch_loss += train_loss.item()
        train_epoch_acc += train_acc.item()
        
        
    # VALIDATION    
    with torch.no_grad():
        
        val_epoch_loss = 0
        val_epoch_acc = 0
        
        model.eval()
        for X_val_batch, y_val_batch in val_loader:
            X_val_batch, y_val_batch = X_val_batch.to(device), y_val_batch.to(device)
            
            y_val_pred = model(X_val_batch)
                        
            val_loss = criterion(y_val_pred, y_val_batch)
            val_acc = multi_acc(y_val_pred, y_val_batch)
            
            val_epoch_loss += val_loss.item()
            val_epoch_acc += val_acc.item()
    loss_stats['train'].append(train_epoch_loss/len(train_loader))
    loss_stats['val'].append(val_epoch_loss/len(val_loader))
    accuracy_stats['train'].append(train_epoch_acc/len(train_loader))
    accuracy_stats['val'].append(val_epoch_acc/len(val_loader))
                              
    
    print(f'Epoch {e+0:03}: | Train Loss: {train_epoch_loss/len(train_loader):.5f} | Val Loss: {val_epoch_loss/len(val_loader):.5f} | Train Acc: {train_epoch_acc/len(train_loader):.3f}| Val Acc: {val_epoch_acc/len(val_loader):.3f}')
# Out:
# Begin training.
#   0%|          | 0/300 [00:00<?, ?it/s]
# Epoch 001: | Train Loss: 0.74335 | Val Loss: 2.21224 | Train Acc: 37.458| Val Acc: 3.125
# Epoch 002: | Train Loss: 0.37030 | Val Loss: 2.47878 | Train Acc: 45.569| Val Acc: 3.125
# Epoch 003: | Train Loss: 0.34184 | Val Loss: 2.43072 | Train Acc: 45.792| Val Acc: 2.344
# Epoch 004: | Train Loss: 0.30999 | Val Loss: 2.63046 | Train Acc: 45.375| Val Acc: 3.125
# Epoch 005: | Train Loss: 0.27615 | Val Loss: 2.49877 | Train Acc: 47.375| Val Acc: 3.125
# Epoch 006: | Train Loss: 0.28906 | Val Loss: 2.64432 | Train Acc: 47.292| Val Acc: 3.906
# Epoch 007: | Train Loss: 0.27670 | Val Loss: 2.45342 | Train Acc: 45.056| Val Acc: 5.469
# Epoch 008: | Train Loss: 0.24912 | Val Loss: 2.54044 | Train Acc: 49.278| Val Acc: 4.688
# Epoch 009: | Train Loss: 0.24521 | Val Loss: 2.54404 | Train Acc: 49.181| Val Acc: 5.469
# Epoch 010: | Train Loss: 0.23456 | Val Loss: 2.33132 | Train Acc: 52.056| Val Acc: 6.250
# Epoch 011: | Train Loss: 0.26723 | Val Loss: 2.29259 | Train Acc: 50.889| Val Acc: 10.938
# Epoch 012: | Train Loss: 0.19322 | Val Loss: 2.41368 | Train Acc: 57.458| Val Acc: 7.812
# Epoch 013: | Train Loss: 0.21496 | Val Loss: 2.34999 | Train Acc: 53.431| Val Acc: 10.156
# Epoch 014: | Train Loss: 0.19821 | Val Loss: 2.36554 | Train Acc: 56.556| Val Acc: 8.594
# Epoch 015: | Train Loss: 0.19276 | Val Loss: 2.27043 | Train Acc: 56.444| Val Acc: 7.812
# Epoch 016: | Train Loss: 0.16645 | Val Loss: 2.31700 | Train Acc: 57.014| Val Acc: 10.938
# Epoch 017: | Train Loss: 0.21118 | Val Loss: 2.21081 | Train Acc: 56.375| Val Acc: 13.281
# Epoch 018: | Train Loss: 0.18783 | Val Loss: 2.24770 | Train Acc: 58.986| Val Acc: 12.500
# Epoch 019: | Train Loss: 0.14334 | Val Loss: 2.21394 | Train Acc: 62.847| Val Acc: 13.281
# Epoch 020: | Train Loss: 0.15461 | Val Loss: 2.23074 | Train Acc: 61.861| Val Acc: 11.719
# Epoch 021: | Train Loss: 0.15866 | Val Loss: 2.10811 | Train Acc: 58.431| Val Acc: 16.406
# Epoch 022: | Train Loss: 0.20800 | Val Loss: 1.98519 | Train Acc: 61.222| Val Acc: 23.438
# Epoch 023: | Train Loss: 0.17441 | Val Loss: 2.16090 | Train Acc: 61.681| Val Acc: 14.062
# Epoch 024: | Train Loss: 0.15274 | Val Loss: 2.16094 | Train Acc: 62.042| Val Acc: 12.500
# Epoch 025: | Train Loss: 0.15195 | Val Loss: 2.12623 | Train Acc: 61.528| Val Acc: 14.844
# Epoch 026: | Train Loss: 0.13683 | Val Loss: 2.14882 | Train Acc: 62.889| Val Acc: 15.625
# Epoch 027: | Train Loss: 0.15955 | Val Loss: 2.07857 | Train Acc: 62.431| Val Acc: 21.094
# Epoch 028: | Train Loss: 0.14822 | Val Loss: 2.05032 | Train Acc: 62.264| Val Acc: 16.406
# Epoch 029: | Train Loss: 0.15022 | Val Loss: 2.06834 | Train Acc: 62.583| Val Acc: 18.750
# Epoch 030: | Train Loss: 0.14226 | Val Loss: 2.03595 | Train Acc: 64.750| Val Acc: 18.750
# Epoch 031: | Train Loss: 0.14693 | Val Loss: 2.00697 | Train Acc: 63.903| Val Acc: 18.750
# Epoch 032: | Train Loss: 0.12704 | Val Loss: 2.23416 | Train Acc: 64.125| Val Acc: 14.844
# Epoch 033: | Train Loss: 0.11613 | Val Loss: 2.06732 | Train Acc: 64.694| Val Acc: 17.969
# Epoch 034: | Train Loss: 0.13726 | Val Loss: 1.93945 | Train Acc: 64.361| Val Acc: 22.656
# Epoch 035: | Train Loss: 0.16535 | Val Loss: 2.32279 | Train Acc: 62.347| Val Acc: 14.062
# Epoch 036: | Train Loss: 0.19658 | Val Loss: 2.24283 | Train Acc: 61.333| Val Acc: 14.844
# Epoch 037: | Train Loss: 0.13890 | Val Loss: 2.10861 | Train Acc: 63.597| Val Acc: 20.312
# Epoch 038: | Train Loss: 0.13414 | Val Loss: 1.90096 | Train Acc: 67.000| Val Acc: 21.094
# Epoch 039: | Train Loss: 0.14066 | Val Loss: 1.94802 | Train Acc: 63.444| Val Acc: 21.875
# Epoch 040: | Train Loss: 0.14844 | Val Loss: 1.94511 | Train Acc: 62.889| Val Acc: 17.969
# Epoch 041: | Train Loss: 0.13585 | Val Loss: 1.87962 | Train Acc: 65.208| Val Acc: 23.438
# Epoch 042: | Train Loss: 0.13998 | Val Loss: 2.09332 | Train Acc: 66.972| Val Acc: 17.188
# Epoch 043: | Train Loss: 0.12356 | Val Loss: 2.11278 | Train Acc: 67.458| Val Acc: 21.875
# Epoch 044: | Train Loss: 0.13935 | Val Loss: 1.93411 | Train Acc: 67.250| Val Acc: 21.875
# Epoch 045: | Train Loss: 0.12243 | Val Loss: 1.86822 | Train Acc: 66.542| Val Acc: 26.562
# Epoch 046: | Train Loss: 0.09891 | Val Loss: 1.87846 | Train Acc: 69.514| Val Acc: 22.656
# Epoch 047: | Train Loss: 0.10894 | Val Loss: 1.82158 | Train Acc: 66.500| Val Acc: 27.344
# Epoch 048: | Train Loss: 0.11156 | Val Loss: 1.80160 | Train Acc: 68.181| Val Acc: 25.781
# Epoch 049: | Train Loss: 0.12920 | Val Loss: 1.99499 | Train Acc: 68.306| Val Acc: 27.344
# Epoch 050: | Train Loss: 0.15528 | Val Loss: 2.11982 | Train Acc: 65.722| Val Acc: 23.438
# Epoch 051: | Train Loss: 0.13514 | Val Loss: 2.00862 | Train Acc: 65.083| Val Acc: 25.000
# Epoch 052: | Train Loss: 0.11752 | Val Loss: 1.93567 | Train Acc: 67.764| Val Acc: 26.562
# Epoch 053: | Train Loss: 0.11632 | Val Loss: 1.99862 | Train Acc: 69.569| Val Acc: 25.000
# Epoch 054: | Train Loss: 0.09486 | Val Loss: 1.81672 | Train Acc: 66.403| Val Acc: 25.781
# Epoch 055: | Train Loss: 0.09165 | Val Loss: 1.74614 | Train Acc: 69.736| Val Acc: 30.469
# Epoch 056: | Train Loss: 0.11688 | Val Loss: 1.81876 | Train Acc: 68.083| Val Acc: 28.906
# Epoch 057: | Train Loss: 0.10495 | Val Loss: 1.90217 | Train Acc: 68.875| Val Acc: 21.094
# Epoch 058: | Train Loss: 0.11949 | Val Loss: 1.82681 | Train Acc: 67.444| Val Acc: 23.438
# Epoch 059: | Train Loss: 0.08778 | Val Loss: 1.78836 | Train Acc: 71.431| Val Acc: 25.781
# Epoch 060: | Train Loss: 0.10411 | Val Loss: 1.72911 | Train Acc: 69.500| Val Acc: 26.562
# Epoch 061: | Train Loss: 0.07962 | Val Loss: 1.70205 | Train Acc: 71.292| Val Acc: 25.000
# Epoch 062: | Train Loss: 0.09990 | Val Loss: 1.75187 | Train Acc: 69.583| Val Acc: 27.344
# Epoch 063: | Train Loss: 0.10426 | Val Loss: 1.79808 | Train Acc: 67.875| Val Acc: 28.906
# Epoch 064: | Train Loss: 0.09358 | Val Loss: 1.72633 | Train Acc: 72.472| Val Acc: 31.250
# Epoch 065: | Train Loss: 0.10067 | Val Loss: 1.86744 | Train Acc: 69.319| Val Acc: 32.812
# Epoch 066: | Train Loss: 0.10835 | Val Loss: 1.75923 | Train Acc: 69.042| Val Acc: 32.812
# Epoch 067: | Train Loss: 0.11755 | Val Loss: 1.77921 | Train Acc: 69.764| Val Acc: 31.250
# Epoch 068: | Train Loss: 0.11678 | Val Loss: 1.79801 | Train Acc: 67.889| Val Acc: 31.250
# Epoch 069: | Train Loss: 0.09182 | Val Loss: 1.78773 | Train Acc: 68.264| Val Acc: 28.906
# Epoch 070: | Train Loss: 0.10202 | Val Loss: 1.97783 | Train Acc: 68.167| Val Acc: 27.344
# Epoch 071: | Train Loss: 0.12459 | Val Loss: 1.71712 | Train Acc: 71.083| Val Acc: 32.031
# Epoch 072: | Train Loss: 0.11310 | Val Loss: 1.64154 | Train Acc: 69.000| Val Acc: 32.812
# Epoch 073: | Train Loss: 0.10854 | Val Loss: 1.60268 | Train Acc: 70.958| Val Acc: 31.250
# Epoch 074: | Train Loss: 0.07580 | Val Loss: 1.67087 | Train Acc: 71.486| Val Acc: 25.000
# Epoch 075: | Train Loss: 0.09251 | Val Loss: 1.93648 | Train Acc: 70.292| Val Acc: 22.656
# Epoch 076: | Train Loss: 0.12305 | Val Loss: 1.74880 | Train Acc: 69.681| Val Acc: 25.781
# Epoch 077: | Train Loss: 0.10779 | Val Loss: 1.74917 | Train Acc: 70.514| Val Acc: 24.219
# Epoch 078: | Train Loss: 0.10524 | Val Loss: 1.64994 | Train Acc: 68.514| Val Acc: 34.375
# Epoch 079: | Train Loss: 0.11336 | Val Loss: 1.80360 | Train Acc: 69.278| Val Acc: 29.688
# Epoch 080: | Train Loss: 0.10183 | Val Loss: 1.76333 | Train Acc: 71.694| Val Acc: 28.906
# Epoch 081: | Train Loss: 0.06689 | Val Loss: 1.71066 | Train Acc: 72.125| Val Acc: 32.812
# Epoch 082: | Train Loss: 0.09484 | Val Loss: 1.71861 | Train Acc: 71.694| Val Acc: 32.031
# Epoch 083: | Train Loss: 0.10013 | Val Loss: 1.70944 | Train Acc: 70.333| Val Acc: 30.469
# Epoch 084: | Train Loss: 0.09130 | Val Loss: 1.68389 | Train Acc: 71.056| Val Acc: 28.906
# Epoch 085: | Train Loss: 0.10903 | Val Loss: 1.60945 | Train Acc: 71.125| Val Acc: 38.281
# Epoch 086: | Train Loss: 0.11254 | Val Loss: 1.61427 | Train Acc: 67.806| Val Acc: 38.281
# Epoch 087: | Train Loss: 0.10267 | Val Loss: 1.59331 | Train Acc: 69.458| Val Acc: 35.156
# Epoch 088: | Train Loss: 0.11606 | Val Loss: 1.70988 | Train Acc: 70.542| Val Acc: 35.156
# Epoch 089: | Train Loss: 0.10841 | Val Loss: 1.67433 | Train Acc: 71.181| Val Acc: 33.594
# Epoch 090: | Train Loss: 0.10364 | Val Loss: 1.76944 | Train Acc: 69.681| Val Acc: 30.469
# Epoch 091: | Train Loss: 0.07818 | Val Loss: 1.78274 | Train Acc: 71.472| Val Acc: 32.031
# Epoch 092: | Train Loss: 0.08954 | Val Loss: 1.76693 | Train Acc: 71.139| Val Acc: 32.031
# Epoch 093: | Train Loss: 0.06982 | Val Loss: 1.56886 | Train Acc: 71.944| Val Acc: 35.938
# Epoch 094: | Train Loss: 0.08995 | Val Loss: 1.64690 | Train Acc: 72.194| Val Acc: 33.594
# Epoch 095: | Train Loss: 0.08203 | Val Loss: 1.72516 | Train Acc: 72.639| Val Acc: 31.250
# Epoch 096: | Train Loss: 0.07281 | Val Loss: 1.67036 | Train Acc: 72.014| Val Acc: 34.375
# Epoch 097: | Train Loss: 0.11814 | Val Loss: 1.76224 | Train Acc: 73.903| Val Acc: 29.688
# Epoch 098: | Train Loss: 0.08202 | Val Loss: 1.69150 | Train Acc: 72.319| Val Acc: 32.031
# Epoch 099: | Train Loss: 0.09368 | Val Loss: 1.60402 | Train Acc: 71.903| Val Acc: 42.188
# Epoch 100: | Train Loss: 0.08007 | Val Loss: 1.63689 | Train Acc: 75.069| Val Acc: 34.375
# Epoch 101: | Train Loss: 0.08000 | Val Loss: 1.65110 | Train Acc: 73.708| Val Acc: 35.156
# Epoch 102: | Train Loss: 0.08262 | Val Loss: 1.71037 | Train Acc: 70.792| Val Acc: 35.938
# Epoch 103: | Train Loss: 0.09503 | Val Loss: 1.66034 | Train Acc: 72.208| Val Acc: 38.281
# Epoch 104: | Train Loss: 0.10274 | Val Loss: 1.87781 | Train Acc: 73.542| Val Acc: 34.375
# Epoch 105: | Train Loss: 0.08000 | Val Loss: 1.67003 | Train Acc: 72.056| Val Acc: 38.281
# Epoch 106: | Train Loss: 0.08811 | Val Loss: 1.68094 | Train Acc: 70.597| Val Acc: 33.594
# Epoch 107: | Train Loss: 0.06460 | Val Loss: 1.70454 | Train Acc: 75.250| Val Acc: 35.938
# Epoch 108: | Train Loss: 0.07588 | Val Loss: 1.65838 | Train Acc: 72.000| Val Acc: 31.250
# Epoch 109: | Train Loss: 0.06251 | Val Loss: 1.58815 | Train Acc: 74.569| Val Acc: 36.719
# Epoch 110: | Train Loss: 0.06844 | Val Loss: 1.55994 | Train Acc: 73.347| Val Acc: 36.719
# Epoch 111: | Train Loss: 0.07490 | Val Loss: 1.60947 | Train Acc: 72.889| Val Acc: 38.281
# Epoch 112: | Train Loss: 0.09777 | Val Loss: 1.62490 | Train Acc: 72.986| Val Acc: 37.500
# Epoch 113: | Train Loss: 0.09278 | Val Loss: 1.71263 | Train Acc: 72.917| Val Acc: 35.938
# Epoch 114: | Train Loss: 0.08828 | Val Loss: 1.59958 | Train Acc: 74.736| Val Acc: 42.969
# Epoch 115: | Train Loss: 0.10416 | Val Loss: 1.60009 | Train Acc: 72.806| Val Acc: 39.844
# Epoch 116: | Train Loss: 0.08823 | Val Loss: 1.71083 | Train Acc: 70.528| Val Acc: 35.156
# Epoch 117: | Train Loss: 0.08595 | Val Loss: 1.51588 | Train Acc: 73.250| Val Acc: 40.625
# Epoch 118: | Train Loss: 0.07722 | Val Loss: 1.69328 | Train Acc: 72.153| Val Acc: 35.156
# Epoch 119: | Train Loss: 0.10714 | Val Loss: 1.47154 | Train Acc: 71.861| Val Acc: 42.969
# Epoch 120: | Train Loss: 0.06552 | Val Loss: 1.67720 | Train Acc: 74.847| Val Acc: 30.469
# Epoch 121: | Train Loss: 0.08115 | Val Loss: 1.65912 | Train Acc: 73.319| Val Acc: 37.500
# Epoch 122: | Train Loss: 0.08205 | Val Loss: 1.58761 | Train Acc: 72.847| Val Acc: 36.719
# Epoch 123: | Train Loss: 0.08177 | Val Loss: 1.64708 | Train Acc: 73.542| Val Acc: 35.156
# Epoch 124: | Train Loss: 0.06280 | Val Loss: 1.56009 | Train Acc: 74.389| Val Acc: 43.750
# Epoch 125: | Train Loss: 0.07386 | Val Loss: 1.61432 | Train Acc: 72.819| Val Acc: 38.281
# Epoch 126: | Train Loss: 0.07274 | Val Loss: 1.71020 | Train Acc: 76.292| Val Acc: 32.812
# Epoch 127: | Train Loss: 0.08071 | Val Loss: 1.63775 | Train Acc: 73.708| Val Acc: 38.281
# Epoch 128: | Train Loss: 0.06399 | Val Loss: 1.72069 | Train Acc: 75.417| Val Acc: 35.156
# Epoch 129: | Train Loss: 0.07678 | Val Loss: 1.68636 | Train Acc: 74.403| Val Acc: 40.625
# Epoch 130: | Train Loss: 0.09156 | Val Loss: 1.61603 | Train Acc: 72.264| Val Acc: 41.406
# Epoch 131: | Train Loss: 0.06453 | Val Loss: 1.62452 | Train Acc: 74.083| Val Acc: 39.844
# Epoch 132: | Train Loss: 0.08570 | Val Loss: 1.61779 | Train Acc: 71.306| Val Acc: 35.156
# Epoch 133: | Train Loss: 0.06769 | Val Loss: 1.58329 | Train Acc: 75.208| Val Acc: 34.375
# Epoch 134: | Train Loss: 0.08396 | Val Loss: 1.50917 | Train Acc: 74.097| Val Acc: 40.625
# Epoch 135: | Train Loss: 0.10723 | Val Loss: 1.73459 | Train Acc: 74.347| Val Acc: 32.031
# Epoch 136: | Train Loss: 0.07965 | Val Loss: 1.64085 | Train Acc: 73.278| Val Acc: 38.281
# Epoch 137: | Train Loss: 0.07700 | Val Loss: 1.62173 | Train Acc: 75.750| Val Acc: 39.844
# Epoch 138: | Train Loss: 0.06667 | Val Loss: 1.61242 | Train Acc: 72.986| Val Acc: 38.281
# Epoch 139: | Train Loss: 0.08043 | Val Loss: 1.59769 | Train Acc: 75.931| Val Acc: 38.281
# Epoch 140: | Train Loss: 0.07248 | Val Loss: 1.54643 | Train Acc: 73.583| Val Acc: 42.969
# Epoch 141: | Train Loss: 0.06981 | Val Loss: 1.61377 | Train Acc: 74.028| Val Acc: 35.938
# Epoch 142: | Train Loss: 0.07919 | Val Loss: 1.48959 | Train Acc: 72.986| Val Acc: 46.094
# Epoch 143: | Train Loss: 0.07006 | Val Loss: 1.62685 | Train Acc: 74.583| Val Acc: 38.281
# Epoch 144: | Train Loss: 0.06736 | Val Loss: 1.52588 | Train Acc: 74.236| Val Acc: 39.062
# Epoch 145: | Train Loss: 0.06710 | Val Loss: 1.53086 | Train Acc: 75.083| Val Acc: 39.844
# Epoch 146: | Train Loss: 0.05842 | Val Loss: 1.54172 | Train Acc: 75.236| Val Acc: 40.625
# Epoch 147: | Train Loss: 0.06805 | Val Loss: 1.51632 | Train Acc: 78.028| Val Acc: 39.844
# Epoch 148: | Train Loss: 0.06469 | Val Loss: 1.51520 | Train Acc: 75.472| Val Acc: 45.312
# Epoch 149: | Train Loss: 0.06231 | Val Loss: 1.48286 | Train Acc: 76.306| Val Acc: 39.844
# Epoch 150: | Train Loss: 0.08193 | Val Loss: 1.80134 | Train Acc: 76.194| Val Acc: 35.938
# Epoch 151: | Train Loss: 0.08572 | Val Loss: 1.60210 | Train Acc: 72.667| Val Acc: 35.938
# Epoch 152: | Train Loss: 0.08578 | Val Loss: 1.53730 | Train Acc: 73.028| Val Acc: 39.844
# Epoch 153: | Train Loss: 0.07087 | Val Loss: 1.56866 | Train Acc: 73.181| Val Acc: 39.844
# Epoch 154: | Train Loss: 0.12120 | Val Loss: 1.69119 | Train Acc: 73.375| Val Acc: 37.500
# Epoch 155: | Train Loss: 0.07822 | Val Loss: 1.52327 | Train Acc: 74.319| Val Acc: 39.844
# Epoch 156: | Train Loss: 0.06596 | Val Loss: 1.53615 | Train Acc: 76.722| Val Acc: 41.406
# Epoch 157: | Train Loss: 0.06852 | Val Loss: 1.55185 | Train Acc: 73.042| Val Acc: 42.188
# Epoch 158: | Train Loss: 0.08384 | Val Loss: 1.69621 | Train Acc: 74.958| Val Acc: 33.594
# Epoch 159: | Train Loss: 0.07778 | Val Loss: 1.49033 | Train Acc: 74.319| Val Acc: 42.188
# Epoch 160: | Train Loss: 0.06584 | Val Loss: 1.63011 | Train Acc: 78.861| Val Acc: 40.625
# Epoch 161: | Train Loss: 0.07265 | Val Loss: 1.62449 | Train Acc: 74.694| Val Acc: 39.062
# Epoch 162: | Train Loss: 0.08618 | Val Loss: 1.76807 | Train Acc: 75.931| Val Acc: 33.594
# Epoch 163: | Train Loss: 0.09028 | Val Loss: 1.81227 | Train Acc: 74.181| Val Acc: 35.156
# Epoch 164: | Train Loss: 0.08951 | Val Loss: 1.86281 | Train Acc: 71.750| Val Acc: 35.156
# Epoch 165: | Train Loss: 0.07636 | Val Loss: 1.75075 | Train Acc: 75.625| Val Acc: 36.719
# Epoch 166: | Train Loss: 0.10180 | Val Loss: 1.67446 | Train Acc: 73.542| Val Acc: 40.625
# Epoch 167: | Train Loss: 0.08475 | Val Loss: 1.73351 | Train Acc: 75.958| Val Acc: 39.062
# Epoch 168: | Train Loss: 0.08298 | Val Loss: 1.78375 | Train Acc: 73.986| Val Acc: 38.281
# Epoch 169: | Train Loss: 0.09179 | Val Loss: 1.70357 | Train Acc: 74.194| Val Acc: 37.500
# Epoch 170: | Train Loss: 0.09040 | Val Loss: 1.67486 | Train Acc: 74.361| Val Acc: 39.062
# Epoch 171: | Train Loss: 0.07688 | Val Loss: 1.67818 | Train Acc: 75.847| Val Acc: 37.500
# Epoch 172: | Train Loss: 0.05637 | Val Loss: 1.66261 | Train Acc: 75.972| Val Acc: 35.938
# Epoch 173: | Train Loss: 0.08349 | Val Loss: 1.60300 | Train Acc: 74.639| Val Acc: 39.844
# Epoch 174: | Train Loss: 0.05693 | Val Loss: 1.66862 | Train Acc: 77.250| Val Acc: 39.062
# Epoch 175: | Train Loss: 0.09013 | Val Loss: 1.71918 | Train Acc: 73.153| Val Acc: 38.281
# Epoch 176: | Train Loss: 0.07876 | Val Loss: 1.68239 | Train Acc: 74.944| Val Acc: 38.281
# Epoch 177: | Train Loss: 0.06120 | Val Loss: 1.61512 | Train Acc: 76.361| Val Acc: 42.188
# Epoch 178: | Train Loss: 0.07145 | Val Loss: 1.63697 | Train Acc: 75.083| Val Acc: 40.625
# Epoch 179: | Train Loss: 0.06427 | Val Loss: 1.71704 | Train Acc: 75.931| Val Acc: 39.844
# Epoch 180: | Train Loss: 0.06443 | Val Loss: 1.66188 | Train Acc: 75.944| Val Acc: 42.969
# Epoch 181: | Train Loss: 0.09112 | Val Loss: 1.64443 | Train Acc: 75.306| Val Acc: 37.500
# Epoch 182: | Train Loss: 0.08140 | Val Loss: 1.62925 | Train Acc: 76.389| Val Acc: 39.844
# Epoch 183: | Train Loss: 0.06256 | Val Loss: 1.64222 | Train Acc: 77.000| Val Acc: 36.719
# Epoch 184: | Train Loss: 0.06598 | Val Loss: 1.53574 | Train Acc: 77.250| Val Acc: 43.750
# Epoch 185: | Train Loss: 0.07321 | Val Loss: 1.68602 | Train Acc: 74.764| Val Acc: 39.062
# Epoch 186: | Train Loss: 0.06483 | Val Loss: 1.59990 | Train Acc: 77.069| Val Acc: 41.406
# Epoch 187: | Train Loss: 0.05508 | Val Loss: 1.57095 | Train Acc: 77.097| Val Acc: 44.531
# Epoch 188: | Train Loss: 0.05463 | Val Loss: 1.68238 | Train Acc: 78.944| Val Acc: 40.625
# Epoch 189: | Train Loss: 0.07911 | Val Loss: 1.54812 | Train Acc: 77.167| Val Acc: 42.188
# Epoch 190: | Train Loss: 0.06668 | Val Loss: 1.78581 | Train Acc: 74.972| Val Acc: 35.156
# Epoch 191: | Train Loss: 0.06442 | Val Loss: 1.59250 | Train Acc: 76.667| Val Acc: 46.094
# Epoch 192: | Train Loss: 0.06720 | Val Loss: 1.52922 | Train Acc: 76.361| Val Acc: 46.875
# Epoch 193: | Train Loss: 0.07097 | Val Loss: 1.59406 | Train Acc: 75.236| Val Acc: 36.719
# Epoch 194: | Train Loss: 0.07604 | Val Loss: 1.63389 | Train Acc: 75.250| Val Acc: 39.062
# Epoch 195: | Train Loss: 0.07539 | Val Loss: 1.64260 | Train Acc: 77.167| Val Acc: 41.406
# Epoch 196: | Train Loss: 0.09815 | Val Loss: 1.72455 | Train Acc: 75.347| Val Acc: 39.062
# Epoch 197: | Train Loss: 0.07109 | Val Loss: 1.54624 | Train Acc: 74.889| Val Acc: 39.844
# Epoch 198: | Train Loss: 0.06771 | Val Loss: 1.62251 | Train Acc: 78.444| Val Acc: 40.625
# Epoch 199: | Train Loss: 0.07467 | Val Loss: 1.66026 | Train Acc: 76.056| Val Acc: 41.406
# Epoch 200: | Train Loss: 0.06547 | Val Loss: 1.62958 | Train Acc: 75.806| Val Acc: 42.188
# Epoch 201: | Train Loss: 0.06272 | Val Loss: 1.65332 | Train Acc: 78.486| Val Acc: 40.625
# Epoch 202: | Train Loss: 0.06545 | Val Loss: 1.55940 | Train Acc: 76.542| Val Acc: 42.969
# Epoch 203: | Train Loss: 0.07482 | Val Loss: 1.56863 | Train Acc: 76.222| Val Acc: 41.406
# Epoch 204: | Train Loss: 0.06646 | Val Loss: 1.60704 | Train Acc: 78.917| Val Acc: 39.062
# Epoch 205: | Train Loss: 0.06433 | Val Loss: 1.54829 | Train Acc: 77.792| Val Acc: 40.625
# Epoch 206: | Train Loss: 0.06703 | Val Loss: 1.49888 | Train Acc: 74.167| Val Acc: 42.969
# Epoch 207: | Train Loss: 0.07588 | Val Loss: 1.57591 | Train Acc: 77.694| Val Acc: 44.531
# Epoch 208: | Train Loss: 0.08607 | Val Loss: 1.68123 | Train Acc: 77.556| Val Acc: 37.500
# Epoch 209: | Train Loss: 0.07186 | Val Loss: 1.68374 | Train Acc: 75.250| Val Acc: 39.844
# Epoch 210: | Train Loss: 0.05433 | Val Loss: 1.68399 | Train Acc: 77.181| Val Acc: 38.281
# Epoch 211: | Train Loss: 0.06478 | Val Loss: 1.50982 | Train Acc: 77.014| Val Acc: 46.875
# Epoch 212: | Train Loss: 0.08645 | Val Loss: 1.67671 | Train Acc: 74.819| Val Acc: 42.188
# Epoch 213: | Train Loss: 0.08374 | Val Loss: 1.57154 | Train Acc: 75.014| Val Acc: 42.969
# Epoch 214: | Train Loss: 0.11136 | Val Loss: 1.61348 | Train Acc: 74.153| Val Acc: 41.406
# Epoch 215: | Train Loss: 0.09859 | Val Loss: 1.66970 | Train Acc: 73.819| Val Acc: 37.500
# Epoch 216: | Train Loss: 0.05922 | Val Loss: 1.50225 | Train Acc: 75.722| Val Acc: 42.188
# Epoch 217: | Train Loss: 0.05129 | Val Loss: 1.43019 | Train Acc: 78.681| Val Acc: 46.875
# Epoch 218: | Train Loss: 0.06667 | Val Loss: 1.62678 | Train Acc: 75.000| Val Acc: 38.281
# Epoch 219: | Train Loss: 0.06114 | Val Loss: 1.57473 | Train Acc: 74.722| Val Acc: 42.969
# Epoch 220: | Train Loss: 0.05647 | Val Loss: 1.54267 | Train Acc: 77.625| Val Acc: 46.875
# Epoch 221: | Train Loss: 0.06048 | Val Loss: 1.55134 | Train Acc: 76.583| Val Acc: 36.719
# Epoch 222: | Train Loss: 0.07341 | Val Loss: 1.60500 | Train Acc: 75.972| Val Acc: 36.719
# Epoch 223: | Train Loss: 0.08509 | Val Loss: 1.63425 | Train Acc: 75.403| Val Acc: 36.719
# Epoch 224: | Train Loss: 0.07400 | Val Loss: 1.56676 | Train Acc: 74.556| Val Acc: 46.094
# Epoch 225: | Train Loss: 0.06212 | Val Loss: 1.55655 | Train Acc: 75.736| Val Acc: 47.656
# Epoch 226: | Train Loss: 0.07276 | Val Loss: 1.65224 | Train Acc: 73.500| Val Acc: 42.969
# Epoch 227: | Train Loss: 0.05268 | Val Loss: 1.51593 | Train Acc: 78.917| Val Acc: 46.875
# Epoch 228: | Train Loss: 0.07554 | Val Loss: 1.52040 | Train Acc: 75.611| Val Acc: 43.750
# Epoch 229: | Train Loss: 0.06820 | Val Loss: 1.49126 | Train Acc: 75.639| Val Acc: 43.750
# Epoch 230: | Train Loss: 0.06814 | Val Loss: 1.48202 | Train Acc: 76.028| Val Acc: 39.062
# Epoch 231: | Train Loss: 0.06340 | Val Loss: 1.56376 | Train Acc: 75.833| Val Acc: 42.188
# Epoch 232: | Train Loss: 0.05465 | Val Loss: 1.49968 | Train Acc: 77.278| Val Acc: 39.844
# Epoch 233: | Train Loss: 0.05262 | Val Loss: 1.55039 | Train Acc: 78.083| Val Acc: 44.531
# Epoch 234: | Train Loss: 0.07274 | Val Loss: 1.48001 | Train Acc: 76.875| Val Acc: 41.406
# Epoch 235: | Train Loss: 0.06226 | Val Loss: 1.50810 | Train Acc: 76.736| Val Acc: 43.750
# Epoch 236: | Train Loss: 0.06335 | Val Loss: 1.51035 | Train Acc: 76.972| Val Acc: 41.406
# Epoch 237: | Train Loss: 0.05623 | Val Loss: 1.54102 | Train Acc: 76.139| Val Acc: 39.844
# Epoch 238: | Train Loss: 0.07130 | Val Loss: 1.51152 | Train Acc: 77.653| Val Acc: 40.625
# Epoch 239: | Train Loss: 0.05340 | Val Loss: 1.50371 | Train Acc: 75.861| Val Acc: 45.312
# Epoch 240: | Train Loss: 0.06544 | Val Loss: 1.60745 | Train Acc: 75.722| Val Acc: 39.844
# Epoch 241: | Train Loss: 0.05835 | Val Loss: 1.52925 | Train Acc: 76.972| Val Acc: 43.750
# Epoch 242: | Train Loss: 0.05793 | Val Loss: 1.63079 | Train Acc: 77.125| Val Acc: 39.844
# Epoch 243: | Train Loss: 0.05763 | Val Loss: 1.58450 | Train Acc: 77.236| Val Acc: 41.406
# Epoch 244: | Train Loss: 0.07063 | Val Loss: 1.50303 | Train Acc: 74.986| Val Acc: 44.531
# Epoch 245: | Train Loss: 0.08325 | Val Loss: 1.73131 | Train Acc: 75.750| Val Acc: 32.812
# Epoch 246: | Train Loss: 0.06190 | Val Loss: 1.64792 | Train Acc: 74.681| Val Acc: 37.500
# Epoch 247: | Train Loss: 0.07213 | Val Loss: 1.65509 | Train Acc: 73.847| Val Acc: 37.500
# Epoch 248: | Train Loss: 0.06266 | Val Loss: 1.53152 | Train Acc: 77.625| Val Acc: 42.188
# Epoch 249: | Train Loss: 0.07224 | Val Loss: 1.43623 | Train Acc: 73.389| Val Acc: 47.656
# Epoch 250: | Train Loss: 0.05601 | Val Loss: 1.50393 | Train Acc: 77.292| Val Acc: 44.531
# Epoch 251: | Train Loss: 0.06757 | Val Loss: 1.59666 | Train Acc: 76.986| Val Acc: 39.062
# Epoch 252: | Train Loss: 0.04796 | Val Loss: 1.58991 | Train Acc: 78.250| Val Acc: 44.531
# Epoch 253: | Train Loss: 0.05380 | Val Loss: 1.64713 | Train Acc: 77.528| Val Acc: 39.062
# Epoch 254: | Train Loss: 0.05520 | Val Loss: 1.51478 | Train Acc: 78.292| Val Acc: 42.188
# Epoch 255: | Train Loss: 0.04951 | Val Loss: 1.56927 | Train Acc: 77.264| Val Acc: 39.844
# Epoch 256: | Train Loss: 0.06919 | Val Loss: 1.47685 | Train Acc: 76.528| Val Acc: 43.750
# Epoch 257: | Train Loss: 0.05661 | Val Loss: 1.56745 | Train Acc: 77.611| Val Acc: 42.188
# Epoch 258: | Train Loss: 0.09159 | Val Loss: 1.52606 | Train Acc: 75.347| Val Acc: 41.406
# Epoch 259: | Train Loss: 0.08710 | Val Loss: 1.75024 | Train Acc: 77.375| Val Acc: 34.375
# Epoch 260: | Train Loss: 0.07708 | Val Loss: 1.69482 | Train Acc: 75.528| Val Acc: 35.938
# Epoch 261: | Train Loss: 0.06366 | Val Loss: 1.64308 | Train Acc: 74.736| Val Acc: 37.500
# Epoch 262: | Train Loss: 0.05550 | Val Loss: 1.63176 | Train Acc: 79.667| Val Acc: 38.281
# Epoch 263: | Train Loss: 0.04506 | Val Loss: 1.54913 | Train Acc: 78.639| Val Acc: 42.188
# Epoch 264: | Train Loss: 0.05140 | Val Loss: 1.67289 | Train Acc: 79.597| Val Acc: 40.625
# Epoch 265: | Train Loss: 0.05758 | Val Loss: 1.55507 | Train Acc: 77.014| Val Acc: 43.750
# Epoch 266: | Train Loss: 0.06236 | Val Loss: 1.52855 | Train Acc: 77.819| Val Acc: 41.406
# Epoch 267: | Train Loss: 0.06762 | Val Loss: 1.54839 | Train Acc: 78.458| Val Acc: 39.062
# Epoch 268: | Train Loss: 0.07016 | Val Loss: 1.54755 | Train Acc: 74.681| Val Acc: 40.625
# Epoch 269: | Train Loss: 0.04950 | Val Loss: 1.54370 | Train Acc: 79.625| Val Acc: 42.188
# Epoch 270: | Train Loss: 0.06038 | Val Loss: 1.41052 | Train Acc: 78.486| Val Acc: 46.094
# Epoch 271: | Train Loss: 0.08297 | Val Loss: 1.54788 | Train Acc: 77.597| Val Acc: 43.750
# Epoch 272: | Train Loss: 0.11503 | Val Loss: 1.55824 | Train Acc: 76.208| Val Acc: 39.844
# Epoch 273: | Train Loss: 0.07069 | Val Loss: 1.62346 | Train Acc: 76.431| Val Acc: 42.969
# Epoch 274: | Train Loss: 0.06250 | Val Loss: 1.53958 | Train Acc: 76.389| Val Acc: 44.531
# Epoch 275: | Train Loss: 0.06022 | Val Loss: 1.42317 | Train Acc: 76.347| Val Acc: 47.656
# Epoch 276: | Train Loss: 0.04937 | Val Loss: 1.51650 | Train Acc: 76.361| Val Acc: 42.969
# Epoch 277: | Train Loss: 0.06518 | Val Loss: 1.60607 | Train Acc: 77.347| Val Acc: 42.188
# Epoch 278: | Train Loss: 0.06894 | Val Loss: 1.58961 | Train Acc: 75.722| Val Acc: 40.625
# Epoch 279: | Train Loss: 0.05216 | Val Loss: 1.65736 | Train Acc: 78.778| Val Acc: 39.844
# Epoch 280: | Train Loss: 0.06239 | Val Loss: 1.49857 | Train Acc: 76.972| Val Acc: 43.750
# Epoch 281: | Train Loss: 0.05182 | Val Loss: 1.61059 | Train Acc: 80.486| Val Acc: 39.844
# Epoch 282: | Train Loss: 0.05273 | Val Loss: 1.61703 | Train Acc: 77.431| Val Acc: 40.625
# Epoch 283: | Train Loss: 0.06075 | Val Loss: 1.54551 | Train Acc: 76.514| Val Acc: 39.844
# Epoch 284: | Train Loss: 0.04848 | Val Loss: 1.49595 | Train Acc: 80.431| Val Acc: 44.531
# Epoch 285: | Train Loss: 0.04911 | Val Loss: 1.58886 | Train Acc: 78.236| Val Acc: 42.188
# Epoch 286: | Train Loss: 0.06580 | Val Loss: 1.57580 | Train Acc: 77.931| Val Acc: 39.062
# Epoch 287: | Train Loss: 0.05053 | Val Loss: 1.56096 | Train Acc: 79.153| Val Acc: 38.281
# Epoch 288: | Train Loss: 0.05247 | Val Loss: 1.54392 | Train Acc: 77.431| Val Acc: 40.625
# Epoch 289: | Train Loss: 0.04730 | Val Loss: 1.61648 | Train Acc: 80.208| Val Acc: 39.062
# Epoch 290: | Train Loss: 0.07264 | Val Loss: 1.46708 | Train Acc: 77.917| Val Acc: 43.750
# Epoch 291: | Train Loss: 0.08412 | Val Loss: 1.51241 | Train Acc: 75.583| Val Acc: 39.844
# Epoch 292: | Train Loss: 0.06448 | Val Loss: 1.63833 | Train Acc: 77.528| Val Acc: 39.062
# Epoch 293: | Train Loss: 0.06717 | Val Loss: 1.67981 | Train Acc: 76.847| Val Acc: 35.938
# Epoch 294: | Train Loss: 0.05369 | Val Loss: 1.55803 | Train Acc: 77.056| Val Acc: 46.875
# Epoch 295: | Train Loss: 0.04315 | Val Loss: 1.47049 | Train Acc: 79.319| Val Acc: 44.531
# Epoch 296: | Train Loss: 0.05489 | Val Loss: 1.53116 | Train Acc: 76.667| Val Acc: 41.406
# Epoch 297: | Train Loss: 0.06048 | Val Loss: 1.67831 | Train Acc: 78.639| Val Acc: 39.062
# Epoch 298: | Train Loss: 0.05452 | Val Loss: 1.55510 | Train Acc: 77.736| Val Acc: 43.750
# Epoch 299: | Train Loss: 0.05651 | Val Loss: 1.53473 | Train Acc: 76.528| Val Acc: 43.750
# Epoch 300: | Train Loss: 0.04758 | Val Loss: 1.66172 | Train Acc: 81.875| Val Acc: 39.062

# %%
# Create dataframes
train_val_acc_df = pd.DataFrame.from_dict(accuracy_stats).reset_index().melt(id_vars=['index']).rename(columns={"index":"epochs"})
train_val_loss_df = pd.DataFrame.from_dict(loss_stats).reset_index().melt(id_vars=['index']).rename(columns={"index":"epochs"})
# Plot the dataframes
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20,7))
sns.lineplot(data=train_val_acc_df, x = "epochs", y="value", hue="variable",  ax=axes[0]).set_title('Train-Val Accuracy/Epoch')
sns.lineplot(data=train_val_loss_df, x = "epochs", y="value", hue="variable", ax=axes[1]).set_title('Train-Val Loss/Epoch')
# Out:
# Text(0.5, 1.0, 'Train-Val Loss/Epoch')

# %%
y_pred_list = []
with torch.no_grad():
    model.eval()
    for X_batch, _ in test_loader:
        X_batch = X_batch.to(device)
        y_test_pred = model(X_batch)
        _, y_pred_tags = torch.max(y_test_pred, dim = 1)
        y_pred_list.append(y_pred_tags.cpu().numpy())
y_pred_list = [a.squeeze().tolist() for a in y_pred_list]

# %%
confusion_matrix_df = pd.DataFrame(confusion_matrix(y_test, y_pred_list)).rename(columns=idx2class, index=idx2class)

sns.heatmap(confusion_matrix_df, annot=True)
# Out:
# <Axes: >

# %%
print(classification_report(y_test, y_pred_list))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       0.10      0.64      0.18        11
#            2       0.78      0.44      0.56       136
#            3       0.57      0.20      0.29       128
#            4       0.27      0.75      0.40        40
#            5       0.00      0.00      0.00         3
#
#     accuracy                           0.38       320
#    macro avg       0.29      0.34      0.24       320
# weighted avg       0.60      0.38      0.41       320
